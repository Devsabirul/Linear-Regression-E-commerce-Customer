# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"D:\Programming\ML_DATA\\Ecommerce Customers")
df
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
df.head(10)
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
# 5         alvareznancy@lucas.biz
# 6          katherine20@yahoo.com
# 7             awatkins@yahoo.com
# 8    vchurch@walter-martinez.com
# 9               bonnie69@lin.biz
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# 5  645 Martha Park Apt. 611\nJeffreychester, MN 6...       FloralWhite
# 6  68388 Reyes Lights Suite 692\nJosephbury, WV 9...     DarkSlateBlue
# ...

# %%
df.keys()
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
df.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
df = df.drop(['Email', 'Address', 'Avatar'],axis=1)

# %%
X = df.drop('Yearly Amount Spent', axis=1)

# %%
X
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership
# 0              34.497268    12.655651        39.577668              4.082621
# 1              31.926272    11.109461        37.268959              2.664034
# 2              33.000915    11.330278        37.110597              4.104543
# 3              34.305557    13.717514        36.721283              3.120179
# 4              33.330673    12.795189        37.536653              4.446308
# ..                   ...          ...              ...                   ...
# 495            33.237660    13.566160        36.417985              3.746573
# 496            34.702529    11.695736        37.190268              3.576526
# 497            32.646777    11.499409        38.332576              4.958264
# 498            33.322501    12.391423        36.840086              2.336485
# 499            33.715981    12.418808        35.771016              2.735160
#
# [500 rows x 4 columns]

# %%
y = df['Yearly Amount Spent']

# %% [markdown]
# # Training Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test, y_train,y_test = train_test_split(X,y, train_size=.70, random_state=51)

# %%
X_test
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership
# 106            32.291756    12.190474        36.152462              3.781823
# 171            31.864833    13.443406        36.878315              2.361087
# 217            32.122365    11.435534        36.223557              4.852842
# 118            32.401732    12.089310        38.309908              3.873338
# 123            31.358477    12.809883        36.549668              3.637701
# ..                   ...          ...              ...                   ...
# 321            33.674027    12.968893        37.333107              3.229451
# 256            34.379394    12.930929        36.360247              3.792712
# 470            32.518197    11.509253        36.599289              3.022676
# 86             33.877779    12.517666        37.151921              2.669942
# 376            32.397422    12.055340        37.685465              3.506968
#
# [150 rows x 4 columns]

# %% [markdown]
# # predict with Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predict = reg.predict(X_test)

# %%
y_test
# Out:
# 106    494.551861
# 171    439.891280
# 217    528.933619
# 118    506.547307
# 123    495.175950
#           ...
# 321    542.412477
# 256    574.654843
# 470    424.728774
# 86     487.379306
# 376    483.796522
# Name: Yearly Amount Spent, Length: 150, dtype: float64

# %%
reg.score(X_test,y_test)
# Out:
# 0.9815374097703966

# %%
df.head(2)
# Out:
#                        Email                                         Address  \
# 0  mstephenson@fernandez.com    835 Frank Tunnel\nWrightmouth, MI 82180-9605
# 1          hduke@hotmail.com  4547 Archer Common\nDiazchester, CA 06566-8576
#
#       Avatar  Avg. Session Length  Time on App  Time on Website  \
# 0     Violet            34.497268    12.655651        39.577668
# 1  DarkGreen            31.926272    11.109461        37.268959
#
#    Length of Membership  Yearly Amount Spent
# 0              4.082621           587.951054
# 1              2.664034           392.204933

# %%
df["Predict Yearly Amount Spent"] = reg.predict(X)

# %%
df.head(5)
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
reg.coef_
# Out:
# array([25.43322441, 38.43780148,  0.58966072, 60.95665592])

# %%
reg.intercept_
# Out:
# -1041.8264580284942

# %%
print("Accuracy of training dataset:", reg.score(X_train,y_train))
print("Accuracy of test dataset:", reg.score(X_test,y_test))
# Out:
# Accuracy of training dataset: 0.9853649091917376
# Accuracy of test dataset: 0.9815374097703966

# %% [markdown]
# # mean_squared_error , mean_absolute_error

# %%
from sklearn.metrics import mean_squared_error , mean_absolute_error

# %%
print('MAE = ', mean_absolute_error(y_test,predict))
# Out:
# MAE =  8.729128519536113

# %%
print('MSE =', mean_squared_error(y_test,predict))
# Out:
# MSE = 115.80865980956442

# %%
df.corr()
# Out:
#                              Avg. Session Length  Time on App  \
# Avg. Session Length                     1.000000    -0.027826
# Time on App                            -0.027826     1.000000
# Time on Website                        -0.034987     0.082388
# Length of Membership                    0.060247     0.029143
# Yearly Amount Spent                     0.355088     0.499328
# Predict Yearly Amount Spent             0.357058     0.504701
#
#                              Time on Website  Length of Membership  \
# Avg. Session Length                -0.034987              0.060247
# Time on App                         0.082388              0.029143
# Time on Website                     1.000000             -0.047582
# Length of Membership               -0.047582              1.000000
# Yearly Amount Spent                -0.002641              0.809084
# Predict Yearly Amount Spent        -0.000477              0.814954
#
# ...

# %%
import seaborn as sns
sns.heatmap(data=X)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (10,10))
sns.pairplot(data = df)
plt.show()
